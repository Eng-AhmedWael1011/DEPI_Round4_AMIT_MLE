# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = np.array([1,2,3,4])
y = np.array([2,2.2,3.6,4.5])

# %%
w = 0
b = 0
alpha = 0.01
num_iteration = 20

# %% [markdown]
# SSE is the array of sum square errors

# %%
sse_values = []
for i in range(num_iteration):
    y_hat = w*x + b

    D_w = 2 * np.sum((y_hat - y)* x)
    D_b = 2 * np.sum(y_hat - y)

    w -= alpha * D_w
    b -= alpha * D_b

    sse = (np.sum((y_hat - y)**2))
    sse_values.append(sse)
    if (i+1) % 20 == 0:
        print(f"iteration {i+1} , SSE: {sse}")
# Out:
# iteration 20 , SSE: 0.3687034101890407

# %%
print(f"Optimized parameter : Bias = {b} , slop = {w}")
# Out:
# Optimized parameter : Bias = 0.46449395643183927 , slop = 1.0211190656858384

# %%
plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
plt.plot(range(num_iteration), sse_values , label="SSE")
plt.xlabel("number of iteration")
plt.ylabel("SSE")
plt.title("SSE Over iteration")
plt.legend()
plt.subplot(1,2,2)
plt.scatter(x,y , color = "blue" , label= "Data points")
plt.plot(x, w*x +b , color = "red" , label = "regression line")
plt.show()

# %%
y = w * x + b
print(y) 

print(y_hat)
# Out:
# [1.48561302 2.50673209 3.52785115 4.54897022]
# [1.48252966 2.50523799 3.52794631 4.55065464]
