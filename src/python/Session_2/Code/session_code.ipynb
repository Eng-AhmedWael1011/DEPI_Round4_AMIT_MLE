# %%
print("my name is {0} , my age is {1}".format("ahmed", 30))
print("my name is {} , my age is {}".format("wael", 50))
print("my name is {x} , my age is {y}".format(x="mohamed", y=55))
# Out:
# my name is ahmed , my age is 30
# my name is wael , my age is 50
# my name is mohamed , my age is 55

# %%
name = "Ahmed"
age = 21
print(f"my name is {name}, my age is {age}")
# Out:
# my name is Ahmed, my age is 21

# %%
name = "Ahmed"
age = 21
course_name = "Machine learning"

print(f"My name is {name}, and I am {age} years old. I am engaged in learning {course_name}")
# Out:
# My name is Ahmed, and I am 21 years old. I am engaged in learning Machine learning

# %%
name = "amit learning"
print(name[5:10:1])
# Out:
# learn

# %%
name = "aMIt Learning"

print(name.upper())
print(name.lower())
print(name.replace('amit','hello'))
print(name.capitalize())
# Out:
# AMIT LEARNING
# amit learning
# aMIt Learning
# Amit learning

# %%
name ='ahmed wael mohamed'
split_name = name.split()
print(split_name)
# Out:
# ['ahmed', 'wael', 'mohamed']

# %%
sent = " ".join(split_name)
sent
# Out:
# 'ahmed wael mohamed'

# %%
print("this is double qoutes: \"hello\" ")
# Out:
# this is double qoutes: "hello"
