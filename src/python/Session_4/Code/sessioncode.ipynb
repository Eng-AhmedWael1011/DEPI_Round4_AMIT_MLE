# %% [markdown]
# # Test

# %%
print("hello")
# Out:
# hello

# %%
def reverse_vocab(s):

    """
    param_1 = receive txt from user\n
    type param: string\n
    return : return string\n
    type return : string\n
    """

    st_1 = s.split(' ')
    reversed_list = st_1[::-1]
    new_str = ' '.join(reversed_list)
    return new_str

x = input("Please enter a sentence to reverse")

print(reverse_vocab(x))
# Out:
# wael Ahemd

# %%
import random

def generate_password(n):
    characters = 'qwertyuiopasdfghjklzxcvbnmABCDEFGHIJKLMNOPQRSTUVW123456789!@#$%^&*0'
    password = ''
    for i in range(n):
        password += random.choice(characters)
        
    return password

length_of_password = int(input("enter the length of the password"))
passkey = print(generate_password(length_of_password))
# Out:
# okhK!SO5v3HyaniWcmUr^IbS9Vk!9&NR

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]

def identify_unique_words(x):
    """
    param_1 = Take list from user
    type param: list

    return: return a dict contains a key {unique outcome} and value {frequancy of the occurance}

    logic: unique words is to convert the list to a set to identify the unique outcomes only

    counts variable: is built in with the list comparhension to build it as dict
    """
    unique_words = set(words)
    # print(unique_words)
    counts  = {word:0 for word in words}
    for i in unique_words:
        for j in x:
            if i == j :
                counts[i] += 1
    return counts


identify_unique_words(words)
# Out:
# {'Welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}

# %%
responses = {
    "hello" : ["hello" , "Hi there!", "Greeting"],
    "how are you" : ["I'm doing well, thank you" , "I'm fine, how are you?"],
    "goodbye" : ["goodbye" , "see you later" , "farwell!"],
    "default": ["I'm sorry, i did not understand.", "could you please rephrase that?"]
}
def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice([responses["default"]])

def chatbot():
    print("chatbot: Hi how can i help you today ?")

    while True:

        user_input = input("user:     ").lower()
        response = get_response(user_input)
        print('chatbot: ' , response)

        if user_input == 'goodbye':
            break

# %%
chatbot()
# Out:
# chatbot: Hi how can i help you today ?
# chatbot:  hello
# chatbot:  I'm fine, how are you?
# chatbot:  ["I'm sorry, i did not understand.", 'could you please rephrase that?']
# chatbot:  farwell!

# %%
'''

this class


'''


class Student_info:
    stud_name = 'depi'
    stud_age = 20
    stud_gpa = 3.99
    gender = 'male'


    def std_info(self):
        print('hello world')

# %%
s1 = Student_info()

# %%
s1.stud_name
s1.std_info()
# Out:
# hello world

# %%
s1.stud_name = "AMIT"

# %%
s1.std_info()
# Out:
# hello world

# %%
class Test: 
    def info(self):
        print(self)

# %%
x = Test()

# %%
x.info()

# %%
class Student:

    def __init__(self):
        print("Hello World")

# %%
s2 = Student()
# Out:
# Hello World

# %%
class PasswordGenerator:

    def __init__(self , length):
        self.characters = 'qwertyuiopasdfghjklzxcvbnmABCDEFGHIJKLMNOPQRSTUVW123456789!@#$%^&*0'
        self.length = int(length)
        self.password = ''

    def generate_password(self):

        for _ in range(self.length):
            self.password += random.choice(self.characters)
    
        return print(self.password)

if __name__ == "__main__":


    generator = PasswordGenerator(8)

    generator.generate_password()
# Out:
# GnCgJ1xm
